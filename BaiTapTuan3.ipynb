# %%
a,b=map(int,input().split())
a^=b
b^=a
a^=b
print(a,b)

# %%
n=int(input())
print("Yes" if n>0 and n&(n-1)==0 else "No")

# %%
m,n=map(float,input().split())
print(int(m//n))

# %%
import math
m,n=map(float,input().split())
print(math.ceil(m/n))

# %%
x=int(input())
print("Even" if x%2==0 else "Odd")

# %%
a,b=map(int,input().split())
print("Yes" if a<0 and b<0 else "No")

# %%
a,b=input().split()
print("True" if len(a)>len(b) else "False")

# %%
a,b,c=map(int,input().split())
print("Yes" if a+b>c and a+c>b and b+c>a else "No")

# %%
a,b,c,d=map(int,input().split())
print(max(a,b,c,d))

# %%
a,b,c=map(int,input().split())
if a+b<=c or a+c<=b or b+c<=a:
print("Không phải tam giác")
elif a==b==c:
    print("Tam giác đều")
elif a==b or a==c or b==c:
    print("Tam giác cân")
else:
    print("Tam giác thường")

# %%
n=int(input())
print("Yes" if n%400==0 or (n%4==0 and n%100!=0) else "No")

# %%
a,b=map(float,input().split())
if a==0 :
    print("Vô số nghiệm"  else "Vô nghiệm" if a==0 else round(-b/a,2))
