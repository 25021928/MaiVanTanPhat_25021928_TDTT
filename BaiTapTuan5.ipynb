# %%
a, b = map(int, input().split())
def Max_Of_Two(a,b):
 if a>b:
  return a
 return b
print(Max_Of_Two(a,b))

# %%
a, b = map(int,input().split())
def swap(a,b):
 return b,a
print(swap(a, b))

# %%
n = int(
