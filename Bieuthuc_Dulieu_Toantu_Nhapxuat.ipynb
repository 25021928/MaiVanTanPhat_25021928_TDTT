# %%
#W2A1
print('Hello, world!')

# %%
x = input()
print('Xin chào', x)

# %%
a, b = map(int, input('Nhập 2 số nguyên =').split())
c = a/b
print(a + b)
print(a - b)
print(a * b)
print(a//b)
print(a%b)
print(format(c,".2f"))

# %%
a1, b1, c1, a2, b2, a3 = map(float, input('Nhập số điểm lần lượt là= ').split())
d = (a1 + b1 + c1 + 2*(a2 + b2) + 3*a3)/10
print(f"{d:.1f}")

# %%
a, b = map(int, input('Nhập 2 số là=').split())
d = a**b
print(d)

# %%
a = input()
print(ord(a))
print(a.upper())

# %%
print(((13**2)*3)+5)
print(13**2*3+5)

# %%
a = float(input())
b = a*9/5 + 32
print(round(b, 2))

# %%
a, b, c = map(str, input().split())
print(f'Hi {c}, {b} and {a}')

# %%
a, b = map(float, input('Thoi gian can nhap la: ').split())
c = a*3600 + b*60
print(c)

# %%
a = int(input('Do dai canh khoi rubic la '))
b = 6*(a**2)
print(f'So mieng dan rieng le can thiet la {b}')

# %%
a, b = map(int, input().split(" x "))
c = a*b
d = c%10
print(f'Chu so hang don vi la {d}')

# %%
a = int(input('So a la '))
b = int(input('So b la '))
print(f'{b} va {a}')

# %%
a = int(input())
b = 6*a*(a-1) + 1
print(f'So sao la {b}')

# %%
print('''Spring
Summer
Autumn
Winter''')

# %%
print('''  *  
 *** 
*****''')

# %%
print('''### # #   ### ###
 #  #  #   #   #
 #  #   #  #   #
 #  #  #   #   #
 #  # #    #   #''')

# %%
print('Monday \nTuesday \nWednesday \nThursday \nFriday \nSaturday \nSunday')

# %%
months = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]

for y in months:
    print(y)

# %%
i = 1
while i <= 10:
    print('Hello, world!')
    i += 1
