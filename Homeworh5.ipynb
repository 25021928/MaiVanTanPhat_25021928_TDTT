# %%
n,m=map(int,input().split());a=[]
for i in range(n):a.append(list(map(int,input().split())))
for i in range(n):
 for j in range(m):print(f"{a[i][j]:>4}",end="")
 print()

# %%
n,m=map(int,input().split());a=[]
for i in range(n):a.append(list(map(int,input().split())))
for i in range(min(n,m)):print(a[i][i],end=" ")
print()
for i in range(min(n,m)):print(a[i][m-i-1],end=" ")

# %%
n,m,k=map(int,input().split());s=0
for i in range(n):
 r=list(map(int,input().split()))
 s+=r[k]
print(s)

# %%
def f(a):
 m=a[0];p=0
 for i in range(len(a)):
  if a[i]>m:
      m=a[i]
      p=i
 return p
a = list(map(int, input().split()))
print(f(a))

# %%
def g(a,k):
 for i in range(len(a)):
  if a[i]==k:return i
 return -1

# %%
d={};x=input().split()
for i in range(len(x)):
 if x[i] in d:d[x[i]]+= (i,)
 else:d[x[i]]=(i,)
print(d)

# %%
def h(a):
 i=0
 for j in range(len(a)):
  if a[j]>a[i]:i=j
 return i

# %%
def r(a,x):
 i=0
 while i<len(a):
  if a[i]<x:a.pop(i)
  else:i+=1
 return a

# %%
def z(a):
 i=0
 for j in range(len(a)):
  if a[j]!=0:a[i],a[j]=a[j],a[i];i+=1
 return a

# %%
a=list(map(int,input().split()))
b=[0]*10
for x in a:b[x]=1
for i in range(10):
 if not b[i]:print(i,end=" ")

# %%
a=list(map(int,input().split()));s=0
for i in range(1,len(a)-1):
 if a[i]>a[i-1] and a[i]>a[i+1]:s+=a[i]
print(s)

# %%
a=list(map(int,input().split()));x=int(input());f=0
for i in range(len(a)):
 if a[i]<x:print(i,end=" ");f=1
if not f:print(-1)

# %%
a=list(map(int,input().split()));t=1;g=1
for i in range(1,len(a)):
 if a[i]<=a[i-1]:t=0
 if a[i]>=a[i-1]:g=0
print("tang" if t else "giam" if g else "vo danh")
