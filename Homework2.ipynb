# %%
a, b = map(float, input().split())
print(f'Dien tich la , {a*b}')
print(f'Chu vi la , {(a+b)*2}')

# %%
a = float(input())
print('Chu vi la , {3.14*a*2}')
print('Dien tich la , {3.14*(a**2)}')

# %%
a, b, c = map(float, input().split())
if a+b>c and a+c>b and b+c>a:
    p = (a+b+c)/2
    if a**2+b**2==c**2 or a**2+c**2==b**2 or b**2+c**2==a**2:
        print('Tam giac vuong')
    elif a==b and b==c and c==a:
        print('Tam giac deu')
    elif a==b or a==c or b==c:
        print('Tam giac can')
    else:
        print('Tam giac thuong')
    print(a+b+c)
    print((p*(p-a)*(p-b)*(p-c))**0.5)
else:
    print('Khong phai tam giac')

# %%
a, b = map(float, input().split())
print(f'{a},"x +", {b}, "= 0"')
print(-b/a)

# %%
a, b, c = map(float, input().split())
delta = b**2-4*a*c
x1 = (-b-delta**0.5)/(2a)
x2 = (-b+delta**0.5)/(2a)
if delta > 0:
    print(x1, x2, sep=" ")
elif delta == 0:
    print(x1)
else:
    print('Vo nghiem')

# %%
a = map(float, input().split())
print(max(a))

# %%
a = map(float, input().split())
print(min(a))

# %%
a, b, m = map(float, input().split())
c, d, n = map(float, input().split())
y = (m*c-a*n)/(b*c-a*d)
x = (m-b*y)/a
print(f'"x = ", {x}, "y = ", {y}')

# %%
a = int(input())
b = a//3600
c = (a%3600)//60
d = a%60
print(f'{b}, 'gio', {c}, 'phut', {d}, 'giay'')

# %%
a, b = map(float, input('Toa do tam O: ').split(';'))
c, d = map(float, input('Toa do iem A: ').split(';'))
R = int(input())
if ((a-c)**2+(b-d)**2)**0.5 == R:
    print('Diem A thuoc duong tron')
else:
    print('Diem A khong thuoc duong tron')

# %%
x, y = map(int, input().split())
print(x**y)
