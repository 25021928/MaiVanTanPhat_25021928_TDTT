# %%
#1
for i in range(100):
    if i % 2 != 0:
        print(i, end=' ')

# %%
#2
for i in range(100):
    if i % 6 == 0:
        print(i, end=' ')

# %%
#3
a = int(input())
b = 0
while b < 10:
    b += 1
    print(f'{a} x {b} = {a*b}')

# %%
#4
a = int(input())
print(' '*(a-1)+'*')
b,c = 1,1
while b < a-1:
    b += 1
    print(' '*(a-b)+'*'+' '*(c)+'*')
    c += 2
print('*'*(2*a-1))

# %%
#5
a = int(input())
b = 0
while b < a:
    b += 1
    a += b
print(a)

# %%
#6
a = int(input())
for i in range(a):
    a += i
print(a)

# %%
#7
a = int(input())
for i in range(a):
    if a % i == 0:
        print(i, end = ' ')

# %%
a,  b = map(int, input().split())
for i in range(1, a):
    if a % i == 0 and b % i ==0 :
        print(i, end = ' ')

# %%
a = int(input())
for i in range(1,a):
    if a / i == i:
        print('Day la so chinh phuong')
if all(a / i != i for i in range(1,a)):
    print('Khong phai so chinh phuong')
# Out:
#  23
# Khong phai so chinh phuong

# %%
a = int(input())
b = 0
for i in range(1, a):
    if a % i == 0:
        b += i
if b == a:
    print('Day la so hoan hao')
else:
    print('Khong phai so hoan hao')
# Out:
#  27
# Khong phai so hoan hao

# %%
a = int(input())
while a <= 0:
    a = int(input())
else:
    print('Dung yeu cau')
# Out:
#  -3
#  -8
#  -60
#  0
#  8
# Dung yeu cau

# %%
a = int(input())
b, c = 0, 0
while c + b + 1 < a:
    b += 1
    c += b
print(b)
# Out:
#  7
# 3

# %%
a = int(input())
b, c = 1, 1
while c <= a:
    b += 1
    c += 1/b
print(b)
# Out:
#  8
# 1674

# %%
a = int(input())
b, c = a, a
while a != -1:
    a = int(input())
    if b < a:
        b = a
    if c > a and a != -1:
        c = a
    if a == -1:
        print(b, c)
# Out:
#  7
#  -6
#  45
#  -1
# 45 -6

# %%
a = int(input())
b = 0
while a > 0:
    a = a//10
    b += 1
print(b)
# Out:
#  45
# 2

# %%
a = int(input())
b, c = 0, 0
while a > 0:
    if (a % 10) % 2 != 0:
        b += 1
    elif (a % 10) % 2 == 0:
        c += 1
    a = a//10
print(f'So chu so le la {b} va so chu so chan la {c}')

# %%
a = int(input())
b = 0
while a > 0:
    b += a%10
    a = a//10
print(b)

# %%
a = int(input())
while a > 1:
    a = a / 3
if a == 1:
    print('a o dang 3^k')
else:
    print('a khong o dang 3^k')

# %%
a = int(input())
b,c = 0,0
while a > 0:
    b = a%10
    a = a //10
    if b in [2, 3, 5, 7]:
        c += 1
print(f'a co {c} chu so la so nguyen to')
